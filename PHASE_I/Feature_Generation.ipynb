# %% [markdown]
# # 2. Feature Generation
#
# This module has the following purpose:
# 1. For every company, and for the periods from 2009Q1 to 2018Q4, identify the CEOs, the CFOs, and the start of their tenure (quarter).
# 2. (See Capstone Project Proposal).

# %% [markdown]
# ## 2.1 CEO/CFO identification
#
# WikiData is not robust enough for this task. In fact, of the 5 first companies in the companies list, only 1 had info on their current CEO. None of the first 5 companies had any information on past CEOs, or any CFO info.
#
# SEC's EDGAR system offers the quartely filings ("10-Q") in plain text format.
# The great thing about the 10-Q forms is that both CEO and CFO must certify a legal form as part of the filing. This form always starts with:
# `I, Steven Roth, certify that:`
# Steven Roth is either CEO or CFO. Further down in this section the officer does sign with name and title, thus yielding CEO or CFO.
#
# Better yet - these 10-Q are addressable via a unique identifier, which is listed in the SUB dataframe. This unique identifier can actually directly be adressed via the URL, and yields a .txt file:
# https://www.sec.gov/Archives/edgar/data/3499/000000349918000023/0000003499-18-000023.txt
#
# Summarized:
# 1. Get list of 10-Q filing codes for each company from the dataframe.
# 2. Access the URL that yields the 10-Q text file.
# 3. Use Regex and/or text matching to identify the officers.
# 4. Use Regex and/or text matching to identify their titles.
#
# This yields:
#
# | CIK        | Quarter           | CEO  | CFO |
# | :------------ |:-------------:| -----:|-----:|
# | 00002354   | 2015Q1 | Jim Jones | Tim Bucks |
# | 00002354   | 2015Q2      |   Jim Jones | Tim Bucks |
# | 00002354 | 2015Q3      | Jane Jackson | Tim Bucks |

# %%
# to restore pickled files
import pickle

# to work with data
import pandas as pd

# to work with folders
import os

# %% [markdown]
# Restore the full dictionary with dataframes to have maximum data flexiblity.

# %%
# restore the pickled dictionary of dataframes
try: DataFrames
except NameError:
    with open('dict_of_dfs_num_pre_sub_tag.p', 'rb') as SECfile:
        DataFrames = pickle.load(SECfile)

# %%
DataFrames['SUB'][['adsh','cik','name','ein','former','changed','afs','wksi','fye','form','period','filed']].head()
# Out:
#                    adsh   cik                               name          ein  \
# 0  0000002178-18-000067  2178     ADAMS RESOURCES & ENERGY, INC.  741753147.0
# 1  0000002488-18-000189  2488         ADVANCED MICRO DEVICES INC  941692300.0
# 2  0000002969-18-000044  2969  AIR PRODUCTS & CHEMICALS INC /DE/  231274455.0
# 3  0000003499-18-000023  3499                     ALEXANDERS INC  510100517.0
# 4  0000003545-18-000108  3545                          ALICO INC  590906081.0
#
#                          former     changed    afs  wksi     fye  form  \
# 0  ADAMS RESOURCES & ENERGY INC  19920703.0  2-ACC     0  1231.0  10-Q
# 1                           NaN         NaN  1-LAF     0  1231.0  10-Q
# 2                           NaN         NaN  1-LAF     1   930.0  10-K
# 3                           NaN         NaN  1-LAF     0  1231.0  10-Q
# 4     ALICO LAND DEVELOPMENT CO  19740219.0  2-ACC     0   930.0  10-K
#
#      period     filed
# 0  20180930  20181107
# 1  20180930  20181031
# 2  20180930  20181120
# 3  20180930  20181029
# 4  20180930  20181206

# %% [markdown]
# Taking a closer look at the Submissions Dataframe:
# * CIK (Company Index Key) is fully contained in the ADSH (unique filing identifier).
# * Former company names, along with the change date (as integer), are shown. This could be helpful for further company research.
# * 'form' lists the form name, making filtering for 10-Qs easy.
# * 'fye' refers the the fiscal year end date.
# * 'period' indicates what quarter-ending-on-date this filing refers to.
# * 'filed' refers to the document filing date.
#
# 'ein', 'afs' and 'wksi' hold no relevance to our analysis (based on a reading of readme.html).
# Retaining only the relevant columns yields:

# %%
sub_relevant_columns = DataFrames['SUB'][['adsh','cik','name','former','changed','fye','form','period']]

# %%
sub_relevant_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6421 entries, 0 to 6420
# Data columns (total 8 columns):
# adsh       6421 non-null object
# cik        6421 non-null int64
# name       6421 non-null object
# former     3596 non-null object
# changed    3596 non-null float64
# fye        6419 non-null float64
# form       6421 non-null object
# period     6421 non-null int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 401.4+ KB

# %% [markdown]
# Data quality is good overall. Only 2 filings appear to be missing Fiscal Year End which is not likely to be important in the analysis. Steps needed to make the data useful for our needs:
# * Filter the table on 10-Q forms.

# %%
filings_to_obtain = sub_relevant_columns[sub_relevant_columns['form'] == '10-Q']

# %%
filings_to_obtain.head()
# Out:
#                    adsh   cik                            name  \
# 0  0000002178-18-000067  2178  ADAMS RESOURCES & ENERGY, INC.
# 1  0000002488-18-000189  2488      ADVANCED MICRO DEVICES INC
# 3  0000003499-18-000023  3499                  ALEXANDERS INC
# 5  0000003570-18-000160  3570             CHENIERE ENERGY INC
# 7  0000004281-18-000127  4281                    ARCONIC INC.
#
#                          former     changed     fye  form    period
# 0  ADAMS RESOURCES & ENERGY INC  19920703.0  1231.0  10-Q  20180930
# 1                           NaN         NaN  1231.0  10-Q  20180930
# 3                           NaN         NaN  1231.0  10-Q  20180930
# 5       BEXY COMMUNICATIONS INC  19940314.0  1231.0  10-Q  20180930
# 7                    ALCOA INC.  20141003.0  1231.0  10-Q  20180930

# %%
# to open the text file
import requests

# to scrape the text file
from bs4 import BeautifulSoup

# to pause the script
from time import sleep
from random import randint

def download_filing(row):
    adsh = str(row['adsh'])
    cik = str(row['cik'])
    adsh_stripped = str(adsh.replace('-', ''))
    url = 'https://www.sec.gov/Archives/edgar/data/' + cik + '/' + adsh_stripped + '/' + adsh + '.txt'
    
    # web scraping best practice to avoid overloading the server
    sleep(randint(2,6))
    r = requests.get(url).text
    print('downloaded ' + url)
    print('starts with ' + r[:50])
    return r


# Add a column 'content' in which the filing content is stored
if not 'filings.p' or 'filings.csv' in os.listdir('.'):
    filings = filings_to_obtain.copy()
    filings['content'] = filings.apply(download_filing, axis=1)
else:
    filings = pd.read_csv('filings.csv', chunksize=10)
# Out:
# downloaded https://www.sec.gov/Archives/edgar/data/2178/000000217818000067/0000002178-18-000067.txt
# starts with <SEC-DOCUMENT>0000002178-18-000067.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/2488/000000248818000189/0000002488-18-000189.txt
# starts with <SEC-DOCUMENT>0000002488-18-000189.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/3499/000000349918000023/0000003499-18-000023.txt
# starts with <SEC-DOCUMENT>0000003499-18-000023.txt : 20181029
#
# downloaded https://www.sec.gov/Archives/edgar/data/3570/000000357018000160/0000003570-18-000160.txt
# starts with <SEC-DOCUMENT>0000003570-18-000160.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/4281/000000428118000127/0000004281-18-000127.txt
# starts with <SEC-DOCUMENT>0000004281-18-000127.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/4457/000000445718000054/0000004457-18-000054.txt
# starts with <SEC-DOCUMENT>0000004457-18-000054.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/4904/000000490418000055/0000004904-18-000055.txt
# starts with <SEC-DOCUMENT>0000004904-18-000055.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/4962/000000496218000121/0000004962-18-000121.txt
# starts with <SEC-DOCUMENT>0000004962-18-000121.txt : 20181023
#
# downloaded https://www.sec.gov/Archives/edgar/data/4969/000000496918000024/0000004969-18-000024.txt
# starts with <SEC-DOCUMENT>0000004969-18-000024.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/4977/000000497718000152/0000004977-18-000152.txt
# starts with <SEC-DOCUMENT>0000004977-18-000152.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/5272/000000527218000043/0000005272-18-000043.txt
# starts with <SEC-DOCUMENT>0000005272-18-000043.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/5513/000000551318000094/0000005513-18-000094.txt
# starts with <SEC-DOCUMENT>0000005513-18-000094.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/6201/000000620118000039/0000006201-18-000039.txt
# starts with <SEC-DOCUMENT>0000006201-18-000039.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/6845/000000684518000021/0000006845-18-000021.txt
# starts with <SEC-DOCUMENT>0000006845-18-000021.txt : 20181009
#
# downloaded https://www.sec.gov/Archives/edgar/data/6885/000000688518000322/0000006885-18-000322.txt
# starts with <SEC-DOCUMENT>0000006885-18-000322.txt : 20181212
#
# downloaded https://www.sec.gov/Archives/edgar/data/7039/000000703918000059/0000007039-18-000059.txt
# starts with <SEC-DOCUMENT>0000007039-18-000059.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/7084/000000708418000039/0000007084-18-000039.txt
# starts with <SEC-DOCUMENT>0000007084-18-000039.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/7332/000000733218000051/0000007332-18-000051.txt
# starts with <SEC-DOCUMENT>0000007332-18-000051.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/7789/000000778918000053/0000007789-18-000053.txt
# starts with <SEC-DOCUMENT>0000007789-18-000053.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/8063/000000806318000029/0000008063-18-000029.txt
# starts with <SEC-DOCUMENT>0000008063-18-000029.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/8670/000000867018000017/0000008670-18-000017.txt
# starts with <SEC-DOCUMENT>0000008670-18-000017.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/8858/000000885818000069/0000008858-18-000069.txt
# starts with <SEC-DOCUMENT>0000008858-18-000069.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/8868/000000886818000051/0000008868-18-000051.txt
# starts with <SEC-DOCUMENT>0000008868-18-000051.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/8947/000000894718000161/0000008947-18-000161.txt
# starts with <SEC-DOCUMENT>0000008947-18-000161.txt : 20181009
#
# downloaded https://www.sec.gov/Archives/edgar/data/9092/000000909218000012/0000009092-18-000012.txt
# starts with <SEC-DOCUMENT>0000009092-18-000012.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/9346/000000934618000090/0000009346-18-000090.txt
# starts with <SEC-DOCUMENT>0000009346-18-000090.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/9984/000000998418000083/0000009984-18-000083.txt
# starts with <SEC-DOCUMENT>0000009984-18-000083.txt : 20181029
#
# downloaded https://www.sec.gov/Archives/edgar/data/10254/000001025418000080/0000010254-18-000080.txt
# starts with <SEC-DOCUMENT>0000010254-18-000080.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/11199/000001119918000045/0000011199-18-000045.txt
# starts with <SEC-DOCUMENT>0000011199-18-000045.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/11544/000001154418000089/0000011544-18-000089.txt
# starts with <SEC-DOCUMENT>0000011544-18-000089.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/12208/000001220818000048/0000012208-18-000048.txt
# starts with <SEC-DOCUMENT>0000012208-18-000048.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/12400/000001240018000016/0000012400-18-000016.txt
# starts with <SEC-DOCUMENT>0000012400-18-000016.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/12927/000001292718000065/0000012927-18-000065.txt
# starts with <SEC-DOCUMENT>0000012927-18-000065.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/13239/000001323918000023/0000013239-18-000023.txt
# starts with <SEC-DOCUMENT>0000013239-18-000023.txt : 20181113
#
# downloaded https://www.sec.gov/Archives/edgar/data/14195/000001419518000043/0000014195-18-000043.txt
# starts with <SEC-DOCUMENT>0000014195-18-000043.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/14272/000001427218000197/0000014272-18-000197.txt
# starts with <SEC-DOCUMENT>0000014272-18-000197.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/14693/000001469318000176/0000014693-18-000176.txt
# starts with <SEC-DOCUMENT>0000014693-18-000176.txt : 20181206
#
# downloaded https://www.sec.gov/Archives/edgar/data/14707/000001470718000050/0000014707-18-000050.txt
# starts with <SEC-DOCUMENT>0000014707-18-000050.txt : 20181212
#
# downloaded https://www.sec.gov/Archives/edgar/data/14930/000001493018000148/0000014930-18-000148.txt
# starts with <SEC-DOCUMENT>0000014930-18-000148.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/15615/000001561518000036/0000015615-18-000036.txt
# starts with <SEC-DOCUMENT>0000015615-18-000036.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/16160/000001616018000096/0000016160-18-000096.txt
# starts with <SEC-DOCUMENT>0000016160-18-000096.txt : 20181001
#
# downloaded https://www.sec.gov/Archives/edgar/data/16732/000001673218000085/0000016732-18-000085.txt
# starts with <SEC-DOCUMENT>0000016732-18-000085.txt : 20181206
#
# downloaded https://www.sec.gov/Archives/edgar/data/16875/000001687518000120/0000016875-18-000120.txt
# starts with <SEC-DOCUMENT>0000016875-18-000120.txt : 20181019
#
# downloaded https://www.sec.gov/Archives/edgar/data/16918/000001691818000074/0000016918-18-000074.txt
# starts with <SEC-DOCUMENT>0000016918-18-000074.txt : 20181004
#
# downloaded https://www.sec.gov/Archives/edgar/data/17843/000001784318000064/0000017843-18-000064.txt
# starts with <SEC-DOCUMENT>0000017843-18-000064.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/18172/000001817218000032/0000018172-18-000032.txt
# starts with <SEC-DOCUMENT>0000018172-18-000032.txt : 20181114
#
# downloaded https://www.sec.gov/Archives/edgar/data/18230/000001823018000293/0000018230-18-000293.txt
# starts with <SEC-DOCUMENT>0000018230-18-000293.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/18255/000001825518000064/0000018255-18-000064.txt
# starts with <SEC-DOCUMENT>0000018255-18-000064.txt : 20181130
#
# downloaded https://www.sec.gov/Archives/edgar/data/18349/000001834918000047/0000018349-18-000047.txt
# starts with <SEC-DOCUMENT>0000018349-18-000047.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/18498/000001849818000048/0000018498-18-000048.txt
# starts with <SEC-DOCUMENT>0000018498-18-000048.txt : 20181213
#
# downloaded https://www.sec.gov/Archives/edgar/data/18926/000001892618000029/0000018926-18-000029.txt
# starts with <SEC-DOCUMENT>0000018926-18-000029.txt : 20181109
# downloaded https://www.sec.gov/Archives/edgar/data/19446/000001944618000066/0000019446-18-000066.txt
# starts with <SEC-DOCUMENT>0000019446-18-000066.txt : 20181130
#
# downloaded https://www.sec.gov/Archives/edgar/data/19612/000001961218000161/0000019612-18-000161.txt
# starts with <SEC-DOCUMENT>0000019612-18-000161.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/19617/000001961718000206/0000019617-18-000206.txt
# starts with <SEC-DOCUMENT>0000019617-18-000206.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/20212/000002021218000042/0000020212-18-000042.txt
# starts with <SEC-DOCUMENT>0000020212-18-000042.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/20286/000002028618000074/0000020286-18-000074.txt
# starts with <SEC-DOCUMENT>0000020286-18-000074.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/20520/000002052018000036/0000020520-18-000036.txt
# starts with <SEC-DOCUMENT>0000020520-18-000036.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/20629/000002062918000105/0000020629-18-000105.txt
# starts with <SEC-DOCUMENT>0000020629-18-000105.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/21076/000002107618000015/0000021076-18-000015.txt
# starts with <SEC-DOCUMENT>0000021076-18-000015.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/21175/000002117518000115/0000021175-18-000115.txt
# starts with <SEC-DOCUMENT>0000021175-18-000115.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/21344/000002134418000042/0000021344-18-000042.txt
# starts with <SEC-DOCUMENT>0000021344-18-000042.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/21665/000002166518000018/0000021665-18-000018.txt
# starts with <SEC-DOCUMENT>0000021665-18-000018.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/22356/000002235618000050/0000022356-18-000050.txt
# starts with <SEC-DOCUMENT>0000022356-18-000050.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/23197/000002319718000097/0000023197-18-000097.txt
# starts with <SEC-DOCUMENT>0000023197-18-000097.txt : 20181206
#
# downloaded https://www.sec.gov/Archives/edgar/data/23217/000002321718000009/0000023217-18-000009.txt
# starts with <SEC-DOCUMENT>0000023217-18-000009.txt : 20181002
#
# downloaded https://www.sec.gov/Archives/edgar/data/24090/000002409018000027/0000024090-18-000027.txt
# starts with <SEC-DOCUMENT>0000024090-18-000027.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/24491/000002449118000024/0000024491-18-000024.txt
# starts with <SEC-DOCUMENT>0000024491-18-000024.txt : 20181029
#
# downloaded https://www.sec.gov/Archives/edgar/data/24545/000002454518000029/0000024545-18-000029.txt
# starts with <SEC-DOCUMENT>0000024545-18-000029.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/24741/000002474118000053/0000024741-18-000053.txt
# starts with <SEC-DOCUMENT>0000024741-18-000053.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/25232/000002523218000032/0000025232-18-000032.txt
# starts with <SEC-DOCUMENT>0000025232-18-000032.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/25475/000002547518000160/0000025475-18-000160.txt
# starts with <SEC-DOCUMENT>0000025475-18-000160.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/25598/000002559818000022/0000025598-18-000022.txt
# starts with <SEC-DOCUMENT>0000025598-18-000022.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/26058/000002605818000092/0000026058-18-000092.txt
# starts with <SEC-DOCUMENT>0000026058-18-000092.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/26172/000002617218000045/0000026172-18-000045.txt
# starts with <SEC-DOCUMENT>0000026172-18-000045.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/26324/000002632418000018/0000026324-18-000018.txt
# starts with <SEC-DOCUMENT>0000026324-18-000018.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/26780/000002678018000015/0000026780-18-000015.txt
# starts with <SEC-DOCUMENT>0000026780-18-000015.txt : 20181029
#
# downloaded https://www.sec.gov/Archives/edgar/data/27419/000002741918000036/0000027419-18-000036.txt
# starts with <SEC-DOCUMENT>0000027419-18-000036.txt : 20181127
#
# downloaded https://www.sec.gov/Archives/edgar/data/27904/000002790418000020/0000027904-18-000020.txt
# starts with <SEC-DOCUMENT>0000027904-18-000020.txt : 20181011
#
# downloaded https://www.sec.gov/Archives/edgar/data/27996/000002799618000105/0000027996-18-000105.txt
# starts with <SEC-DOCUMENT>0000027996-18-000105.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/28412/000002841218000159/0000028412-18-000159.txt
# starts with <SEC-DOCUMENT>0000028412-18-000159.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/28823/000002882318000164/0000028823-18-000164.txt
# starts with <SEC-DOCUMENT>0000028823-18-000164.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/28917/000002891718000521/0000028917-18-000521.txt
# starts with <SEC-DOCUMENT>0000028917-18-000521.txt : 20181206
#
# downloaded https://www.sec.gov/Archives/edgar/data/29332/000002933218000077/0000029332-18-000077.txt
# starts with <SEC-DOCUMENT>0000029332-18-000077.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/29644/000002964418000036/0000029644-18-000036.txt
# starts with <SEC-DOCUMENT>0000029644-18-000036.txt : 20181207
#
# downloaded https://www.sec.gov/Archives/edgar/data/29905/000002990518000059/0000029905-18-000059.txt
# starts with <SEC-DOCUMENT>0000029905-18-000059.txt : 20181018
#
# downloaded https://www.sec.gov/Archives/edgar/data/100790/000002991518000024/0000029915-18-000024.txt
# starts with <SEC-DOCUMENT>0000029915-18-000024.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/29915/000002991518000026/0000029915-18-000026.txt
# starts with <SEC-DOCUMENT>0000029915-18-000026.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/29989/000002998918000019/0000029989-18-000019.txt
# starts with <SEC-DOCUMENT>0000029989-18-000019.txt : 20181016
#
# downloaded https://www.sec.gov/Archives/edgar/data/30554/000003055418000013/0000030554-18-000013.txt
# starts with <SEC-DOCUMENT>0000030554-18-000013.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/30625/000003062518000075/0000030625-18-000075.txt
# starts with <SEC-DOCUMENT>0000030625-18-000075.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/30697/000003069718000012/0000030697-18-000012.txt
# starts with <SEC-DOCUMENT>0000030697-18-000012.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/31107/000003110718000037/0000031107-18-000037.txt
# starts with <SEC-DOCUMENT>0000031107-18-000037.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/31791/000003179118000018/0000031791-18-000018.txt
# starts with <SEC-DOCUMENT>0000031791-18-000018.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/31978/000003197818000049/0000031978-18-000049.txt
# starts with <SEC-DOCUMENT>0000031978-18-000049.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/33185/000003318518000041/0000033185-18-000041.txt
# starts with <SEC-DOCUMENT>0000033185-18-000041.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/33213/000003321318000014/0000033213-18-000014.txt
# starts with <SEC-DOCUMENT>0000033213-18-000014.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/34067/000003406718000034/0000034067-18-000034.txt
# starts with <SEC-DOCUMENT>0000034067-18-000034.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/34088/000003408818000048/0000034088-18-000048.txt
# starts with <SEC-DOCUMENT>0000034088-18-000048.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/34563/000003456318000055/0000034563-18-000055.txt
# starts with <SEC-DOCUMENT>0000034563-18-000055.txt : 20181109
#
# downloaded https://www.sec.gov/Archives/edgar/data/34782/000003478218000097/0000034782-18-000097.txt
# starts with <SEC-DOCUMENT>0000034782-18-000097.txt : 20181018
#
# downloaded https://www.sec.gov/Archives/edgar/data/34903/000003490318000030/0000034903-18-000030.txt
# starts with <SEC-DOCUMENT>0000034903-18-000030.txt : 20181031
# downloaded https://www.sec.gov/Archives/edgar/data/36047/000003604718000115/0000036047-18-000115.txt
# starts with <SEC-DOCUMENT>0000036047-18-000115.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/36966/000003696618000037/0000036966-18-000037.txt
# starts with <SEC-DOCUMENT>0000036966-18-000037.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/37785/000003778518000076/0000037785-18-000076.txt
# starts with <SEC-DOCUMENT>0000037785-18-000076.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/37808/000003780818000028/0000037808-18-000028.txt
# starts with <SEC-DOCUMENT>0000037808-18-000028.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/37996/000003799618000084/0000037996-18-000084.txt
# starts with <SEC-DOCUMENT>0000037996-18-000084.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/38009/000003800918000237/0000038009-18-000237.txt
# starts with <SEC-DOCUMENT>0000038009-18-000237.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/38725/000003872518000191/0000038725-18-000191.txt
# starts with <SEC-DOCUMENT>0000038725-18-000191.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/39263/000003926318000044/0000039263-18-000044.txt
# starts with <SEC-DOCUMENT>0000039263-18-000044.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/39899/000003989918000041/0000039899-18-000041.txt
# starts with <SEC-DOCUMENT>0000039899-18-000041.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/39911/000003991118000155/0000039911-18-000155.txt
# starts with <SEC-DOCUMENT>0000039911-18-000155.txt : 20181130
#
# downloaded https://www.sec.gov/Archives/edgar/data/40211/000004021118000083/0000040211-18-000083.txt
# starts with <SEC-DOCUMENT>0000040211-18-000083.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/40533/000004053318000060/0000040533-18-000060.txt
# starts with <SEC-DOCUMENT>0000040533-18-000060.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/40545/000004054518000081/0000040545-18-000081.txt
# starts with <SEC-DOCUMENT>0000040545-18-000081.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/40729/000004072918000138/0000040729-18-000138.txt
# starts with <SEC-DOCUMENT>0000040729-18-000138.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/40888/000004088818000034/0000040888-18-000034.txt
# starts with <SEC-DOCUMENT>0000040888-18-000034.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/40987/000004098718000034/0000040987-18-000034.txt
# starts with <SEC-DOCUMENT>0000040987-18-000034.txt : 20181022
#
# downloaded https://www.sec.gov/Archives/edgar/data/42316/000004231618000057/0000042316-18-000057.txt
# starts with <SEC-DOCUMENT>0000042316-18-000057.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/42888/000004288818000053/0000042888-18-000053.txt
# starts with <SEC-DOCUMENT>0000042888-18-000053.txt : 20181024
#
# downloaded https://www.sec.gov/Archives/edgar/data/45012/000004501218000168/0000045012-18-000168.txt
# starts with <SEC-DOCUMENT>0000045012-18-000168.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/45876/000004587618000142/0000045876-18-000142.txt
# starts with <SEC-DOCUMENT>0000045876-18-000142.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/45919/000004591918000062/0000045919-18-000062.txt
# starts with <SEC-DOCUMENT>0000045919-18-000062.txt : 20181108
#
# downloaded https://www.sec.gov/Archives/edgar/data/45947/000004594718000032/0000045947-18-000032.txt
# starts with <SEC-DOCUMENT>0000045947-18-000032.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/46080/000004608018000142/0000046080-18-000142.txt
# starts with <SEC-DOCUMENT>0000046080-18-000142.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/46195/000004619518000059/0000046195-18-000059.txt
# starts with <SEC-DOCUMENT>0000046195-18-000059.txt : 20181022
#
# downloaded https://www.sec.gov/Archives/edgar/data/46250/000004625018000031/0000046250-18-000031.txt
# starts with <SEC-DOCUMENT>0000046250-18-000031.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/47111/000004711118000049/0000047111-18-000049.txt
# starts with <SEC-DOCUMENT>0000047111-18-000049.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/48039/000004803918000068/0000048039-18-000068.txt
# starts with <SEC-DOCUMENT>0000048039-18-000068.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/48287/000004828718000203/0000048287-18-000203.txt
# starts with <SEC-DOCUMENT>0000048287-18-000203.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/49071/000004907118000123/0000049071-18-000123.txt
# starts with <SEC-DOCUMENT>0000049071-18-000123.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/49196/000004919618000063/0000049196-18-000063.txt
# starts with <SEC-DOCUMENT>0000049196-18-000063.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/49600/000004960018000029/0000049600-18-000029.txt
# starts with <SEC-DOCUMENT>0000049600-18-000029.txt : 20181022
#
# downloaded https://www.sec.gov/Archives/edgar/data/49754/000004975418000018/0000049754-18-000018.txt
# starts with <SEC-DOCUMENT>0000049754-18-000018.txt : 20181031
#
# downloaded https://www.sec.gov/Archives/edgar/data/49826/000004982618000106/0000049826-18-000106.txt
# starts with <SEC-DOCUMENT>0000049826-18-000106.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/50863/000005086318000029/0000050863-18-000029.txt
# starts with <SEC-DOCUMENT>0000050863-18-000029.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/51253/000005125318000020/0000051253-18-000020.txt
# starts with <SEC-DOCUMENT>0000051253-18-000020.txt : 20181105
#
# downloaded https://www.sec.gov/Archives/edgar/data/51434/000005143418000041/0000051434-18-000041.txt
# starts with <SEC-DOCUMENT>0000051434-18-000041.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/51548/000005154818000033/0000051548-18-000033.txt
# starts with <SEC-DOCUMENT>0000051548-18-000033.txt : 20181004
#
# downloaded https://www.sec.gov/Archives/edgar/data/51644/000005164418000066/0000051644-18-000066.txt
# starts with <SEC-DOCUMENT>0000051644-18-000066.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/52795/000005279518000024/0000052795-18-000024.txt
# starts with <SEC-DOCUMENT>0000052795-18-000024.txt : 20181023
#
# downloaded https://www.sec.gov/Archives/edgar/data/52827/000005282718000041/0000052827-18-000041.txt
# starts with <SEC-DOCUMENT>0000052827-18-000041.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/54381/000005438118000053/0000054381-18-000053.txt
# starts with <SEC-DOCUMENT>0000054381-18-000053.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/54480/000005448018000201/0000054480-18-000201.txt
# starts with <SEC-DOCUMENT>0000054480-18-000201.txt : 20181019
#
# downloaded https://www.sec.gov/Archives/edgar/data/55135/000005513518000027/0000055135-18-000027.txt
# starts with <SEC-DOCUMENT>0000055135-18-000027.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/55242/000005524218000033/0000055242-18-000033.txt
# starts with <SEC-DOCUMENT>0000055242-18-000033.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/55772/000005577218000039/0000055772-18-000039.txt
# starts with <SEC-DOCUMENT>0000055772-18-000039.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/55785/000005578518000069/0000055785-18-000069.txt
# starts with <SEC-DOCUMENT>0000055785-18-000069.txt : 20181022
#
# downloaded https://www.sec.gov/Archives/edgar/data/56701/000005670118000044/0000056701-18-000044.txt
# starts with <SEC-DOCUMENT>0000056701-18-000044.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/57515/000005751518000031/0000057515-18-000031.txt
# starts with <SEC-DOCUMENT>0000057515-18-000031.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/58492/000005849218000014/0000058492-18-000014.txt
# starts with <SEC-DOCUMENT>0000058492-18-000014.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/59440/000005944018000042/0000059440-18-000042.txt
# starts with <SEC-DOCUMENT>0000059440-18-000042.txt : 20181109
# downloaded https://www.sec.gov/Archives/edgar/data/59478/000005947818000256/0000059478-18-000256.txt
# starts with <SEC-DOCUMENT>0000059478-18-000256.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/59527/000005952718000032/0000059527-18-000032.txt
# starts with <SEC-DOCUMENT>0000059527-18-000032.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/59558/000005955818000037/0000059558-18-000037.txt
# starts with <SEC-DOCUMENT>0000059558-18-000037.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/60667/000006066718000203/0000060667-18-000203.txt
# starts with <SEC-DOCUMENT>0000060667-18-000203.txt : 20181206
#
# downloaded https://www.sec.gov/Archives/edgar/data/61398/000006139818000031/0000061398-18-000031.txt
# starts with <SEC-DOCUMENT>0000061398-18-000031.txt : 20181107
#
# downloaded https://www.sec.gov/Archives/edgar/data/62709/000006270918000039/0000062709-18-000039.txt
# starts with <SEC-DOCUMENT>0000062709-18-000039.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/62996/000006299618000062/0000062996-18-000062.txt
# starts with <SEC-DOCUMENT>0000062996-18-000062.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/63908/000006390818000064/0000063908-18-000064.txt
# starts with <SEC-DOCUMENT>0000063908-18-000064.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/64040/000006404018000183/0000064040-18-000183.txt
# starts with <SEC-DOCUMENT>0000064040-18-000183.txt : 20181026
#
# downloaded https://www.sec.gov/Archives/edgar/data/64996/000006499618000043/0000064996-18-000043.txt
# starts with <SEC-DOCUMENT>0000064996-18-000043.txt : 20181030
#
# downloaded https://www.sec.gov/Archives/edgar/data/65011/000006501118000126/0000065011-18-000126.txt
# starts with <SEC-DOCUMENT>0000065011-18-000126.txt : 20181109
#
# downloaded https://www.sec.gov/Archives/edgar/data/65270/000006527018000041/0000065270-18-000041.txt
# starts with <SEC-DOCUMENT>0000065270-18-000041.txt : 20181206
#
# downloaded https://www.sec.gov/Archives/edgar/data/65984/000006598418000229/0000065984-18-000229.txt
# starts with <SEC-DOCUMENT>0000065984-18-000229.txt : 20181106
#
# downloaded https://www.sec.gov/Archives/edgar/data/66382/000006638218000055/0000066382-18-000055.txt
# starts with <SEC-DOCUMENT>0000066382-18-000055.txt : 20181010
#
# downloaded https://www.sec.gov/Archives/edgar/data/66570/000006657018000048/0000066570-18-000048.txt
# starts with <SEC-DOCUMENT>0000066570-18-000048.txt : 20181025
#
# downloaded https://www.sec.gov/Archives/edgar/data/66756/000006675618000088/0000066756-18-000088.txt
# starts with <SEC-DOCUMENT>0000066756-18-000088.txt : 20181101
#
# downloaded https://www.sec.gov/Archives/edgar/data/67215/000006721518000050/0000067215-18-000050.txt
# starts with <SEC-DOCUMENT>0000067215-18-000050.txt : 20181121
#
# downloaded https://www.sec.gov/Archives/edgar/data/67716/000006771618000070/0000067716-18-000070.txt
# starts with <SEC-DOCUMENT>0000067716-18-000070.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/68505/000006850518000029/0000068505-18-000029.txt
# starts with <SEC-DOCUMENT>0000068505-18-000029.txt : 20181102
#
# downloaded https://www.sec.gov/Archives/edgar/data/68622/000006862218000011/0000068622-18-000011.txt
# starts with <SEC-DOCUMENT>0000068622-18-000011.txt : 20181113
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-66581a6593d1> in <module>
#      26 if not 'filings.p' or 'filings.csv' in os.listdir('.'):
#      27     filings = filings_to_obtain.copy()
# ---> 28     filings['content'] = filings.apply(download_filing, axis=1)
#      29 else:
#      30     filings = pd.read_csv('filings.csv', chunksize=10)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     249                                           axis=self.axis,
#     250                                           dummy=dummy,
# --> 251                                           labels=labels)
#     252                 return self.obj._constructor_sliced(result, index=labels)
#     253             except Exception:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.reduce()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-8-66581a6593d1> in download_filing(row)
#      16
#      17     # web scraping best practice to avoid overloading the server
# ---> 18     sleep(randint(2,6))
#      19     r = requests.get(url).text
#      20     print('downloaded ' + url)
#
# KeyboardInterrupt:

# %%
try: filings.head()
except: next(filings).head()

# %%
if not 'filings.p' in os.listdir('.'):
    with open('filings.p', 'wb') as picklefile:
        pickle.dump(filings, picklefile)

# %%
import re

def regex_officers(filing_text):
    expression = r'I, (.+?), certify that'
    match = re.findall(expression, filing_text)
    return match

# officers = filings.
 
# filings['officers'] = filings['content'].apply(regex_officers)

# filings.head()

# %%
# Write the full filings file to CSV. Reason: CSV can be read in chunks, which is a hard necessity
# given the data size (40-50GB).

if not 'filings.csv' in os.listdir('.'):
    filings.to_csv('filings.csv')

# %% [markdown]
# ## Recap
#
# To recap, here is what has been accomplished so far:
# 1. Acquire all filings from the SEC.
# 2. Stored the filings to disk (45GB).
# 3. Created a first draft of the REGEX that will extract officer names.
